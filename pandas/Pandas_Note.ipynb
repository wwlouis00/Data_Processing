# %%
from io import SEEK_CUR
import pandas as pd
import csv
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
import os
import time
import datetime
from datetime import datetime, timedelta
import statistics
import numpy as np
from openpyxl import load_workbook
from heapq import nsmallest
from pandas.core.indexes.base import Index
from pandas.core.series import Series
#---------------------------------------------------------------------------
path = "."
# most_recent = max(csvs, key=lambda x: os.stat(os.path.join(path, x)).st_mtime)
#存檔為現在輸出的時間
now_output_time = str(datetime.now().strftime('%Y-%m-%d %H-%M-%S'))+"_pandas_output.csv"
#----讀取資料---
df = pd.read_csv('data/2021年10月27日.txt',delimiter='\t')
#-----陣列與變數宣告------
MA=1
channelNum = 8
channelList = []
channelList_MA = []
Channel_Total = len(df.columns) - 2

#----列出幾筆資料---
print("開啟檔案名稱:2021年10月27日.txt")
print("-" * 100)
print("直: " + str(len(df.index)) + " 列: " + str(len(df.columns)-2))
print("共 " + str(len(df.index)*(len(df.columns)-2))+" 資料")
print("總共時間為:  " + str(len(df.index)/60) + "分" + str(len(df.index)%60))
print("<"+"-" * 100+">")

df.columns = ['Time','Index','CH1','CH2','CH3','CH4','CH5','CH6','CH7','CH8']

CH3 = []
CH4 = []
CH_T_On = []
CH_T_Off = []
column, row = 3, 5
gap_result_large = []
gap_result_small = []
# print(df)
for ch in range(1,9,1):
    if ch == 1:
        array2D  = [[df.loc[i,'CH'+ str(ch)] for i in range(len(df.index))]]
    else:
        array2D.append([df.loc[i, 'CH'+str(ch)] for i in range(len(df.index))])        
for i in range(0,8,1):
    T_On = []
    T_Off = []
    T_issue = []
    for ch in range (0,len(df.index)-1,1):
        a = array2D[i][ch+1] - array2D[i][ch]        
        if a < 0 and array2D[i][ch] > 109:
            T_On.append(array2D[i][ch])
        elif a > 0 and 73 < array2D[i][ch] < 74:
            T_Off.append(array2D[i][ch])
        elif a == 0 and array2D[i][ch] == -204.8:
            T_issue.append(array2D[i][ch])
    if array2D[i][0] == -204.8 or array2D[i][2] == array2D[i][3]:
        for j in range(1,9,1):
            T_On.append(-204.8)
            T_Off.append(-204.8)

    print("CH"+str(i+1))
    print(T_On)
    print(T_Off)

    CH_T_On.append(T_On[0])
    CH_T_Off.append(T_Off[0])

print("<"+"-" * 100+">")
print("T_On CH1 ~ CH8: ") 
print(CH_T_On)
print("T_Off CH1 ~ CH8: ") 
print(CH_T_Off)


#另存成新的CSV檔案
try:
    print("<"+ "-" * 10 + "Result"+ "-" * 10 + ">")
    # df.to_csv('./'+now_output_time,encoding="utf_8_sig")
    print('Save New file successful!')
except:
    print("失敗並且確認資料格式是否出錯!")
# Out:
# 開啟檔案名稱:2021年10月27日.txt
# ----------------------------------------------------------------------------------------------------
# 直: 300 列: 8
# 共 2400 資料
# 總共時間為:  5.0分0
# <---------------------------------------------------------------------------------------------------->
# CH1
# [109.6, 109.4, 109.1, 109.8, 109.3]
# [73.7, 73.8, 73.7, 73.8, 73.9]
# CH2
# [-204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8]
# [-204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8]
# CH3
# [-204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8]
# [-204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8]
# CH4
# [-204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8]
# [-204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8]
# CH5
# [-204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8]
# [-204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8]
# CH6
# [-204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8]
# [-204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8]
# CH7
# [-204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8]
# [-204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8]
# CH8
# [-204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8]
# [-204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8]
# <---------------------------------------------------------------------------------------------------->
# T_On CH1 ~ CH8
# [109.6, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8]
# T_Off CH1 ~ CH8
# [73.7, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8, -204.8]
# <----------Result---------->
# Save New file successful!

# %%
import pandas as pd

df = pd.read_csv('pokemon_data.csv')

# print(df.head(5))

# df_xlsx = pd.read_excel('pokemon_data.xlsx')
# print(df_xlsx.head(3))

# df = pd.read_csv('pokemon_data.txt', delimiter='\t')

# print(df.head(5))

df['HP']
# Out:
# 0      45
# 1      60
# 2      80
# 3      80
# 4      39
#        ..
# 795    50
# 796    50
# 797    80
# 798    80
# 799    80
# Name: HP, Length: 800, dtype: int64

# %%
import numpy as np
import pandas as pd
# df = pd.DataFrame(np.random.randn(4,2),index=['a', 'a', 'b', 'b'])
# print(df)

a = [{i for i in range(1,2,1)},{j for j in range(1,5,1)},{k for k in range(1,3,1)}]
print(a)
# Out:
# [{1}, {1, 2, 3, 4}, {1, 2}]

# %%
import pandas as pd
from datetime import datetime, timedelta

# data = pd.Series()
# data.max() 找到最大值
# data.median() 計算中位數
# data = data*2 放大兩倍
df = pd.read_csv('pokemon_data.txt',delimiter='\t')
df.sort_values(['Type 1', 'HP'], ascending=[1,0])
print(df)
now_output_time = str(datetime.now().strftime('%Y-%m-%d %H-%M-%S'))+"output.csv"
df.to_csv('./'+now_output_time,encoding="utf_8_sig")
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 12 columns]
